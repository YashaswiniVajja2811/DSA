# %%
class SegmentTree:
    def __init__(self, arr):
        self.n = len(arr)
        self.tree = [0] * (4 * self.n)
        self.build(arr, 0, 0, self.n - 1)

    def build(self, arr, node, start, end):
        if start == end:
            self.tree[node] = arr[start]
        else:
            mid = (start + end) // 2
            self.build(arr, 2 * node + 1, start, mid)
            self.build(arr, 2 * node + 2, mid + 1, end)
            self.tree[node] = max(self.tree[2 * node + 1], self.tree[2 * node + 2])

    def query(self, node, start, end, left, right):
        if right < start or end < left:
            return float('-inf')
        if left <= start and end <= right:
            return self.tree[node]
        mid = (start + end) // 2
        left_res = self.query(2 * node + 1, start, mid, left, right)
        right_res = self.query(2 * node + 2, mid + 1, end, left, right)
        return max(left_res, right_res)

# Taking user input
arr = list(map(int, input("Enter stock prices (space-separated): ").split()))
seg_tree = SegmentTree(arr)
left, right = map(int, input("Enter range (left right) to query max price: ").split())
print("Max stock price in range:", seg_tree.query(0, 0, len(arr) - 1, left, right))
# Out:
# Enter stock prices (space-separated): 5 3 8 6 10 7 2 9
# Enter range (left right) to query max price: 2 5
# Max stock price in range: 10
