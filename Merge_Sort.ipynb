# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

# Taking user input
arr = list(map(int, input("Enter numbers to sort (space-separated): ").split()))
merge_sort(arr)
print("Sorted Array:", arr)
# Out:
# Enter numbers to sort (space-separated): 5 3 8 6 10 7 2 9
# Sorted Array: [2, 3, 5, 6, 7, 8, 9, 10]
